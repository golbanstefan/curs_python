# %% [markdown]
# # 📊 Temă 2: Versiunea cu Hint-uri și Structură
#
# Acest notebook conține **structura funcțiilor** și **hint-uri detaliate** pentru fiecare exercițiu.
#
# **Folosiți-l când:**
# - Aveți nevoie de ajutor pentru a începe
# - Vreți să vedeți structura corectă a funcției
# - Sunteți blocat și nu știți ce pași să urmați
#
# **NU** este o copiere directă a soluțiilor - trebuie să completați logica!

# %%
# Date de lucru
date_regiuni_raw = [
    {"regiune": "Chișinău ", "populatie": 532513, "rata_ocupare": 67.5, "venit_mediu": 8750, 
     "rata_alfabetizare": 99.8, "sector_dominant": "servicii", "numar_intreprinderi": 15420, "rata_somaj": 5.2},
    {"regiune": "Bălți", "populatie": 102457, "rata_ocupare": 63.2, "venit_mediu": 6420, 
     "rata_alfabetizare": 98.5, "sector_dominant": "Industrie", "numar_intreprinderi": 3840, "rata_somaj": 6.8},
    {"regiune": "  Cahul", "populatie": 28763, "rata_ocupare": None, "venit_mediu": 5340, 
     "rata_alfabetizare": 97.2, "sector_dominant": "agricultura", "numar_intreprinderi": 1250, "rata_somaj": 8.4},
    {"regiune": "Ungheni", "populatie": 32828, "rata_ocupare": 61.4, "venit_mediu": None, 
     "rata_alfabetizare": 98.1, "sector_dominant": "Agricultură", "numar_intreprinderi": 1580, "rata_somaj": 7.9},
    {"regiune": "Soroca", "populatie": 22196, "rata_ocupare": 58.3, "venit_mediu": 5120, 
     "rata_alfabetizare": 97.8, "sector_dominant": "AGRICULTURĂ", "numar_intreprinderi": 980, "rata_somaj": None},
    {"regiune": "Orhei", "populatie": 33641, "rata_ocupare": 64.7, "venit_mediu": 6210, 
     "rata_alfabetizare": 98.3, "sector_dominant": "industrie", "numar_intreprinderi": 2150, "rata_somaj": 6.2},
    {"regiune": "Edineț", "populatie": 15624, "rata_ocupare": 56.8, "venit_mediu": 4890, 
     "rata_alfabetizare": 97.5, "sector_dominant": "Agricultură", "numar_intreprinderi": 720, "rata_somaj": 9.1},
    {"regiune": "Comrat", "populatie": 20113, "rata_ocupare": 60.2, "venit_mediu": 5670, 
     "rata_alfabetizare": 98.7, "sector_dominant": "Agricultură", "numar_intreprinderi": 1120, "rata_somaj": 7.5},
    {"regiune": "Strășeni ", "populatie": 18376, "rata_ocupare": 62.8, "venit_mediu": 5980, 
     "rata_alfabetizare": 98.0, "sector_dominant": "Servicii", "numar_intreprinderi": 1340, "rata_somaj": 6.5},
    {"regiune": "Hîncești", "populatie": 16900, "rata_ocupare": 59.5, "venit_mediu": 5230, 
     "rata_alfabetizare": None, "sector_dominant": "Agricultură", "numar_intreprinderi": 890, "rata_somaj": 8.2}
]

# %% [markdown]
# ## 🧹 Exercițiul 1: Curățarea textului
#
# **Hint:** Folosiți două metode pe șir: `.strip()` și `.title()`

# %%
def curata_text(text):
    # HINT: Pașii sunt:
    # 1. Eliminați spațiile cu .strip()
    # 2. Convertiti la Title Case cu .title()
    # 3. Returnați rezultatul
    
    # TODO: Scrieți codul aici
    pass

# Test
# print(curata_text("  Cahul"))  # Ar trebui: "Cahul"
# print(curata_text("servicii"))  # Ar trebui: "Servicii"

# %% [markdown]
# ## 🧹 Exercițiul 2: Tratarea valorilor lipsă
#
# **Hint:** Parcurgeți lista, verificați None, calculați media

# %%
def calculeaza_medie_camp(lista_regiuni, nume_camp):
    # HINT: Structura:
    # 1. Inițializați suma = 0, count = 0
    # 2. Pentru fiecare regiune în lista_regiuni:
    #      - Extrageți valoarea: regiune[nume_camp]
    #      - Dacă valoare is not None:
    #          - suma += valoare
    #          - count += 1
    # 3. Returnați suma / count (verificați count > 0!)
    
    suma = 0
    count = 0
    
    # TODO: Completați logica aici
    
    return suma / count if count > 0 else 0

# Test
# medie = calculeaza_medie_camp(date_regiuni_raw, "venit_mediu")
# print(f"Venit mediu: {medie:.2f}")

# %% [markdown]
# ## 🧹 Exercițiul 3: Completarea valorilor lipsă

# %%
def completeaza_valori_lipsa(lista_regiuni, nume_camp, valoare_inlocuire):
    # HINT: Parcurgeți lista, verificați None, înlocuiți
    for regiune in lista_regiuni:
        # TODO: Verificați dacă regiune[nume_camp] is None
        # TODO: Dacă da, setați regiune[nume_camp] = valoare_inlocuire
        pass
    
    return lista_regiuni

# %% [markdown]
# ## 🧹 Exercițiul 4: Curățare completă
#
# **Hint:** Combinați funcțiile anterioare!

# %%
def curata_date_complete(lista_regiuni):
    # HINT: Pașii sunt:
    # 1. Creați o copie a listei (parcurgeți cu for, creați dicționare noi)
    lista_curatata = []
    for regiune in lista_regiuni:
        # TODO: Creați un dicționar nou cu aceleași date
        # HINT: regiune_noua = {}; for key, value in regiune.items(): ...
        pass
    
    # 2. Curățați câmpurile text pentru fiecare regiune
    for regiune in lista_curatata:
        # TODO: regiune["regiune"] = curata_text(regiune["regiune"])
        # TODO: regiune["sector_dominant"] = curata_text(...)
        pass
    
    # 3. Calculați mediile pentru câmpurile cu None
    campuri_numerice = ["rata_ocupare", "venit_mediu", "rata_alfabetizare", "rata_somaj"]
    medii = {}
    for camp in campuri_numerice:
        # TODO: medii[camp] = calculeaza_medie_camp(...)
        pass
    
    # 4. Completați valorile lipsă
    for camp in campuri_numerice:
        # TODO: completeaza_valori_lipsa(lista_curatata, camp, medii[camp])
        pass
    
    return lista_curatata

# %% [markdown]
# ## 📊 Exercițiul 7: Statistici naționale
#
# **Hint:** Creați variabile pentru acumulare, apoi calculați mediile

# %%
def calculeaza_statistici_nationale(lista_regiuni):
    # HINT: Structura:
    # Inițializați variabilele
    populatie_totala = 0
    suma_venituri = 0
    # TODO: Adăugați alte variabile pentru suma_rata_ocupare, suma_rata_somaj, etc.
    
    numar_regiuni = len(lista_regiuni)
    
    # Parcurgeți și acumulați
    for regiune in lista_regiuni:
        populatie_totala += regiune["populatie"]
        # TODO: Adăugați celelalte acumulări
        pass
    
    # Calculați mediile
    # TODO: venit_mediu_national = suma_venituri / numar_regiuni
    
    # Returnați dicționar
    return {
        "numar_regiuni": numar_regiuni,
        "populatie_totala": populatie_totala,
        # TODO: Adăugați restul cheilor
    }

# %% [markdown]
# ## 📊 Exercițiul 11: Gruparea pe sectoare
#
# **Hint:** Folosiți un dicționar cu liste ca valori

# %%
def grupeaza_dupa_sector(lista_regiuni):
    # HINT: Algoritmul:
    grupare = {}  # Dicționar gol
    
    for regiune in lista_regiuni:
        sector = regiune["sector_dominant"]
        nume_regiune = regiune["regiune"]
        
        # TODO: Verificați dacă sectorul există în grupare
        # HINT: if sector not in grupare:
        #           grupare[sector] = []  # creați listă nouă
        
        # TODO: Adăugați regiunea la lista sectorului
        # HINT: grupare[sector].append(nume_regiune)
        pass
    
    return grupare

# %% [markdown]
# ## 📊 Exercițiul 13: Găsirea extremelor
#
# **Hint:** Inițializați cu prima regiune, apoi comparați

# %%
def gaseste_extreme(lista_regiuni, camp, tip="max"):
    # HINT: Algoritmul:
    # Verificați că lista nu e goală
    if len(lista_regiuni) == 0:
        return {"regiune": None, "valoare": None}
    
    # Inițializați cu prima regiune
    regiune_extrema = lista_regiuni[0]["regiune"]
    valoare_extrema = lista_regiuni[0][camp]
    
    # Parcurgeți restul (de la index 1)
    for regiune in lista_regiuni[1:]:
        valoare_curenta = regiune[camp]
        
        # TODO: Dacă tip == "max":
        #           Dacă valoare_curenta > valoare_extrema:
        #               Actualizați valoare_extrema și regiune_extrema
        # TODO: Altfel (tip == "min"):
        #           Dacă valoare_curenta < valoare_extrema:
        #               Actualizați
        pass
    
    return {
        "regiune": regiune_extrema,
        "valoare": valoare_extrema
    }

# %% [markdown]
# ## 📊 Exercițiul 14: Top N regiuni
#
# **Hint:** Creați lista de perechi, sortați cu bubble sort, returnați primele N

# %%
def top_regiuni(lista_regiuni, camp, n=5, descrescator=True):
    # HINT: Algoritmul în 3 pași:
    
    # Pas 1: Creați lista de perechi
    perechi = []
    for regiune in lista_regiuni:
        # TODO: Adăugați dicționar cu "regiune" și "valoare"
        pass
    
    # Pas 2: Sortați cu bubble sort
    # TODO: Bubble sort - comparați perechi[i] cu perechi[j]
    # HINT: for i in range(len(perechi)):
    #           for j in range(i + 1, len(perechi)):
    #               if descrescator:
    #                   if perechi[i]["valoare"] < perechi[j]["valoare"]:
    #                       # swap: temp = perechi[i]; perechi[i] = perechi[j]; ...
    
    # Pas 3: Returnați primele n
    return perechi[:n]

# %% [markdown]
# ## 📊 Exercițiul 15: Comparație
#
# **Hint:** Găsiți cele două dicționare, apoi comparați fiecare câmp

# %%
def compara_regiuni(lista_regiuni, nume1, nume2):
    # HINT: Pașii:
    
    # 1. Găsiți cele două regiuni
    regiune1 = None
    regiune2 = None
    
    for regiune in lista_regiuni:
        # TODO: Dacă regiune["regiune"] == nume1: regiune1 = regiune
        # TODO: Dacă regiune["regiune"] == nume2: regiune2 = regiune
        pass
    
    # 2. Verificați că le-ați găsit
    if regiune1 is None or regiune2 is None:
        print("Eroare: O regiune nu a fost găsită!")
        return
    
    # 3. Afișați header
    print(f"\n{'='*60}")
    print(f"  COMPARAȚIE: {nume1} vs {nume2}")
    print(f"{'='*60}\n")
    
    # 4. Comparați fiecare câmp
    # TODO: Pentru "populatie", "venit_mediu", etc.:
    #       - Afișați valorile ambelor regiuni
    #       - Calculați diferența
    #       - Afișați care are mai mult
    
    # HINT: Funcție helper:
    def compara_camp(nume_camp, camp, unitate=""):
        val1 = regiune1[camp]
        val2 = regiune2[camp]
        print(f"{nume_camp}:")
        print(f"  {nume1}: {val1:,.2f} {unitate}")
        print(f"  {nume2}: {val2:,.2f} {unitate}")
        
        diferenta = val1 - val2
        if diferenta > 0:
            print(f"  → {nume1} are cu {abs(diferenta):,.2f} {unitate} mai mult\n")
        elif diferenta < 0:
            print(f"  → {nume2} are cu {abs(diferenta):,.2f} {unitate} mai mult\n")
        else:
            print(f"  → Valori egale\n")
    
    # Folosiți funcția helper
    compara_camp("Populație", "populatie", "locuitori")
    # TODO: Adăugați pentru celelalte câmpuri

# %% [markdown]
# ## 🎁 Exercițiul BONUS: Dashboard complet
#
# **Hint:** Folosiți TOATE funcțiile pe care le-ați creat!

# %%
def genereaza_raport_complet(lista_regiuni):
    # HINT: Structura:
    print("\n" + "="*70)
    print("  📊 RAPORT STATISTIC COMPLET")
    print("="*70)
    
    # Secțiunea 1: Statistici generale
    # TODO: Apelați calculeaza_statistici_nationale()
    # TODO: Afișați rezultatele
    
    # Secțiunea 2: Top 3 regiuni
    # TODO: Apelați top_regiuni() pentru diferite câmpuri
    # TODO: Afișați rezultatele
    
    # Secțiunea 3: Analiza pe sectoare
    # TODO: Apelați grupeaza_dupa_sector()
    # TODO: Pentru fiecare sector, calculeaza_statistici_sector()
    # TODO: Afișați rezultatele
    
    # Secțiunea 4: Regiuni cu nevoi speciale
    # TODO: Parcurgeți lista și găsiți regiuni cu șomaj > 8%
    # TODO: Găsiți regiuni cu venit < 5500
    
    # Secțiunea 5: Distribuție pe dimensiuni
    # TODO: Creați dicționar pentru a număra regiuni per dimensiune
    # TODO: Afișați distribuția
    
    pass

# %% [markdown]
# ## 💡 Sfaturi Generale
#
# ### Când folosiți acest notebook:
# 1. **Citiți hint-urile** cu atenție
# 2. **Completați TODO-urile** pas cu pas
# 3. **Testați frecvent** - după fiecare TODO
# 4. **Dacă tot nu merge** - consultați soluțiile complete
#
# ### Pattern-uri comune:
#
# **Parcurgere și acumulare:**
# ```python
# suma = 0
# for element in lista:
#     suma += element["camp"]
# ```
#
# **Verificare None:**
# ```python
# if valoare is not None:
#      #procesează
# ```
#
# **Creare dicționar dinamic:**
# ```python
# dictionar = {}
# if cheie not in dictionar:
#     dictionar[cheie] = []
# dictionar[cheie].append(valoare)
# ```
#
# **Găsire max/min:**
# ```python
# valoare_max = lista[0]
# for element in lista[1:]:
#     if element > valoare_max:
#         valoare_max = element
# ```
#
# ### Debugging:
# ```python
# # Adăugați print() pentru a vedea ce se întâmplă
# print(f"DEBUG: valoare={valoare}, tip={type(valoare)}")
# ```
#
# **Succes! 🚀**
