# %% [markdown]
# # 🧮 Exercițiu cu Dicționare în Python
#
# **Sarcină:** Creează și manipulează un dicționar cu informații demografice. Urmează pașii comentați din cod.

# %%
# Pasul 1: Creează un dicționar cu chei demografice (ex: "Populație", "Vârsta medie")
# Pasul 2: Adaugă o nouă pereche cheie-valoare în dicționar
# Pasul 3: Actualizează valoarea unei chei existente
# Pasul 4: Extrage valoarea unei chei specifice
# Pasul 5: Afișează dicționarul final și valoarea extrasă

# %% [markdown]
# ## ✅ Soluție (execută doar după ce ai încercat singur)

# %%
# Soluție: Manipularea unui dicționar demografic

# Pasul 1
demographics = {
    "Populație": 500000,
    "Vârsta Medie": 35,
    "Procent Urban": 70
}

# Pasul 2
demographics["Rata Șomajului"] = 5.2

# Pasul 3
demographics["Vârsta Medie"] = 36

# Pasul 4
populatie = demographics["Populație"]

# Pasul 5
print(f"Dicționar demografic: {demographics}")
print(f"Populație extrasă: {populatie}")
# Out:
# Dicționar demografic: {'Populație': 500000, 'Vârsta Medie': 36, 'Procent Urban': 70, 'Rata Șomajului': 5.2}
# Populație extrasă: 500000
