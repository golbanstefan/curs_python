# %% [markdown]
# # 🐍 Dicționare în Python
#
# Dicționarele sunt structuri de date **mutable**, care asociază chei unice cu valori. Sunt foarte utile pentru date structurate și căutări rapide.

# %% [markdown]
# ## 🔑 Caracteristici cheie
#
# - **Perechi cheie-valoare**: fiecare element este o cheie (immutable) și o valoare (de orice tip).
# - **Dimensiune dinamică**: dicționarele pot crește sau micșora.
# - **Eficiență**: operațiile de acces, inserare și ștergere sunt rapide.
# - **Metode utile**: `.get()`, `.update()`, `.pop()` etc.
# - **Dicționare imbricate**: pot conține alte dicționare pentru structuri complexe.

# %% [markdown]
# ## 📌 Când să folosim dicționare?
#
# - Când avem nevoie de identificatori unici (ex: profiluri utilizatori).
# - Când facem mapări (ex: traducere valori).
# - Când reprezentăm date structurate (ex: obiecte JSON).

# %% [markdown]
# ## 🧪 Exemplu interactiv

# %%
# Exemplu: Operații cu dicționare

# Creare dicționar
student = {
    "name": "Alice",
    "age": 25,
    "major": "Computer Science"
}

# Adăugare pereche nouă
student["gpa"] = 3.8

# Actualizare valoare
student["age"] = 26

# Accesare sigură
gpa = student.get("gpa", "Indisponibil")

# Ștergere cheie
del student["major"]

# Iterare peste chei și valori
for key, value in student.items():
    print(f"{key}: {value}")

# Dicționar imbricat
grades = {
    "Alice": {"math": 95, "science": 90},
    "Bob": {"math": 80, "science": 85}
}
print(f"Nota lui Alice la Matematică: {grades['Alice']['math']}")
print(f"Nota lui Bob la Știință: {grades['Bob']['science']}")
# Out:
# name: Alice
# age: 26
# gpa: 3.8
# Nota lui Alice la Matematică: 95
# Nota lui Bob la Știință: 85

# %% [markdown]
# ## 🧠 Exerciții practice

# %% [markdown]
# ### ✏️ Exercițiul 1: Creează un dicționar pentru o carte
# - Chei: `title`, `author`, `year`, `pages`
# - Afișează toate cheile și valorile

# %%
# TODO: completează
book = {
    "title": "...",
    "author": "...",
    "year": 0,
    "pages": 0
}
for key, value in book.items():
    print(f"{key}: {value}")
# Out:
# title: ...
# author: ...
# year: 0
# pages: 0

# %% [markdown]
# ### ✏️ Exercițiul 2: Folosește `.get()` și `.update()`
# - Verifică dacă `publisher` există (folosește `.get()`)
# - Adaugă un `publisher` folosind `.update()`

# %%
# TODO: completează
print("Publisher:", book.get("publisher", "Nu există"))
book.update({"publisher": "Editura X"})
print("Publisher actualizat:", book["publisher"])
# Out:
# Publisher: Nu există
# Publisher actualizat: Editura X
