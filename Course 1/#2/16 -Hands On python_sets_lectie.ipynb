# %% [markdown]
# # 🔷 Seturi în Python
#
# Seturile sunt colecții neordonate de elemente unice. Sunt utile pentru testarea apartenenței, eliminarea duplicatelor și operații matematice precum reuniune, intersecție și diferență.

# %% [markdown]
# ## ⚙️ Caracteristici ale seturilor
#
# - **Creare**: folosind acolade `{}` sau funcția `set()`.
# - **Elemente unice**: duplicatele sunt eliminate automat.
# - **Mutabilitate**: seturile sunt mutabile, dar elementele trebuie să fie imutabile.
# - **Operații matematice**: `|` reuniune, `&` intersecție, `-` diferență, `^` diferență simetrică.
# - **Metode comune**: `.add()`, `.remove()`, `.discard()`, `.pop()`, `.clear()`.
# - **frozenset**: o versiune imutabilă a unui set.

# %% [markdown]
# ## 🧪 Exemplu interactiv

# %%
# Exemplu de seturi Python

# Creăm două seturi
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}

# Operații cu seturi
union_set = set_a | set_b
intersection_set = set_a & set_b
difference_set = set_a - set_b
symmetric_difference_set = set_a ^ set_b

# Adăugare și eliminare elemente
set_a.add(7)
set_b.discard(3)

# frozenset (set imutabil)
immutable_set = frozenset([8, 9, 10])

# Afișare rezultate
print(f"Set A: {set_a}")
print(f"Set B: {set_b}")
print(f"Reuniune: {union_set}")
print(f"Intersecție: {intersection_set}")
print(f"Diferență (A - B): {difference_set}")
print(f"Diferență Simetrică: {symmetric_difference_set}")
print(f"Frozenset: {immutable_set}")
print(f"8 este în frozenset? {8 in immutable_set}")
# Out:
# Set A: {1, 2, 3, 4, 7}
# Set B: {4, 5, 6}
# Reuniune: {1, 2, 3, 4, 5, 6}
# Intersecție: {3, 4}
# Diferență (A - B): {1, 2}
# Diferență Simetrică: {1, 2, 5, 6}
# Frozenset: frozenset({8, 9, 10})
# 8 este în frozenset? True

# %% [markdown]
# ## 🧠 Exerciții practice

# %% [markdown]
# ### ✏️ Exercițiul 1: Creează două seturi cu numere întregi
# - Afișează reuniunea, intersecția și diferența acestora.

# %%
# TODO: completează
a = {1, 2, 3}
b = {3, 4, 5}

print("Reuniune:", a | b)
print("Intersecție:", a & b)
print("Diferență a - b:", a - b)
# Out:
# Reuniune: {1, 2, 3, 4, 5}
# Intersecție: {3}
# Diferență a - b: {1, 2}

# %% [markdown]
# ### ✏️ Exercițiul 2: Lucrează cu `frozenset`
# - Creează un `frozenset` și verifică dacă un element aparține acestuia.

# %%
# TODO: completează
fs = frozenset([10, 20, 30])
print("20 este în frozenset?", 20 in fs)
# Out:
# 20 este în frozenset? True
