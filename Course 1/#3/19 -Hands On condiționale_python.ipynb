# %% [markdown]
# # 🔍 Înțelegerea Condiționalelor în Python
#
# Condiționalele ne permit să controlăm fluxul execuției unui program în funcție de anumite condiții. Sunt esențiale pentru luarea deciziilor în Python.

# %% [markdown]
# ## 🔑 Concepte de Bază
# - `if`: execută un bloc de cod dacă condiția este `True`
# - `elif`: verifică o altă condiție dacă precedentele sunt `False`
# - `else`: execută un bloc de cod dacă toate celelalte sunt `False`

# %% [markdown]
# ## 🧮 Operatori de Comparație
# - `==`: egal cu
# - `!=`: diferit de
# - `>`: mai mare decât
# - `<`: mai mic decât
# - `>=`: mai mare sau egal cu
# - `<=`: mai mic sau egal cu

# %% [markdown]
# ## 🔗 Operatori Logici
# - `and`: ambele condiții trebuie să fie `True`
# - `or`: cel puțin una dintre condiții trebuie să fie `True`
# - `not`: inversează valoarea de adevăr a condiției

# %% [markdown]
# ## 🧪 Exemplu: Categorisirea unui scor de integrare socială

# %%
# Exemplu: clasificare scor integrare

scor = 85

if scor >= 90:
    categorie = "Excelent"
elif scor >= 70:
    categorie = "Bun"
elif scor >= 50:
    categorie = "Acceptabil"
else:
    categorie = "Necesită îmbunătățire"

print(f"Scor: {scor}")
print(f"Categorie: {categorie}")

# Validare scor
if 0 <= scor <= 100:
    print("Scorul este valid.")
else:
    print("Scor invalid.")
# Out:
# Scor: 85
# Categorie: Bun
# Scorul este valid.

# %% [markdown]
# ## 🧠 Exerciții Practice

# %% [markdown]
# ### ✏️ Exercițiul 1: Clasifică un scor introdus de utilizator
# - Citește un scor de la utilizator (input)
# - Aplică același model de clasificare ca mai sus

# %%
# TODO: completează
# scor = int(input("Introdu scorul: "))

# %% [markdown]
# ### ✏️ Exercițiul 2: Verifică validitatea a două scoruri
# - Creează două variabile `x` și `y`
# - Verifică dacă ambele sunt între 0 și 100 folosind `and`
# - Verifică dacă cel puțin una este validă cu `or`

# %%
# TODO: completează
x = 45
y = 110

# Verificări logice aici
