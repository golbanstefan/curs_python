# %% [markdown]
# # 🧩 Funcții în Python
#
# Funcțiile sunt blocuri de cod reutilizabile, concepute pentru a efectua sarcini specifice. Ele ajută la organizarea și modularizarea programelor.

# %% [markdown]
# ## ✅ De ce să folosim funcții?
# - **Reutilizare:** Scrii funcția o singură dată și o folosești de mai multe ori.
# - **Modularitate:** Problemele complexe devin mai ușor de rezolvat prin părți mai mici.
# - **Claritate:** Codul devine mai ușor de citit.
# - **Depanare:** Testarea și depanarea sunt mai simple cu cod segmentat.

# %% [markdown]
# ## 🔧 Tipuri de argumente
# - **Argumente poziționale**: transmise în ordinea din definiția funcției
# - **Argumente cu nume (keyword)**: specificate prin nume pentru claritate
# - **Argumente implicite**: au o valoare prestabilită
# - **Argumente variabile**: `*args` pentru poziționale multiple, `**kwargs` pentru keyword multiple

# %%
# Exemplu: funcții cu tipuri de argumente și returnare valori

def arie_dreptunghi(lungime, latime=10):
    """Calculează aria unui dreptunghi."""
    return lungime * latime

def afiseaza_elemente(*elemente):
    """Afișează toate elementele primite ca argumente."""
    for e in elemente:
        print(e)

def salut_formatat(salut, nume):
    """Formatează un mesaj de salut."""
    return f"{salut}, {nume}!"

def sumar_date(*args, **kwargs):
    """Afișează date poziționale și cu cheie."""
    print("Argumente poziționale:", args)
    print("Argumente keyword:", kwargs)

# Apeluri:
print(arie_dreptunghi(5))
print(arie_dreptunghi(5, 4))
afiseaza_elemente("mar", "banana", "cireșe")
print(salut_formatat(nume="Ion", salut="Bună"))
sumar_date(1, 2, 3, nume="Maria", varsta=28)
# Out:
# 50
# 20
# mar
# banana
# cireșe
# Bună, Ion!
# Argumente poziționale: (1, 2, 3)
# Argumente keyword: {'nume': 'Maria', 'varsta': 28}

# %% [markdown]
# ## 🧠 Exerciții Practice

# %% [markdown]
# ### ✏️ Exercițiul 1: Creează o funcție `saluta_utilizator(nume)` care afișează `Salut, <nume>!`

# %%
# TODO: scrie funcția aici

# %% [markdown]
# ### ✏️ Exercițiul 2: Creează o funcție `putere(x, p=2)` care returnează x la puterea p

# %%
# TODO: scrie funcția aici

# %% [markdown]
# ### ✏️ Exercițiul 3: Creează o funcție `info_utilizator(**kwargs)` care primește date ca nume, vârstă, email și le afișează

# %%
# TODO: scrie funcția aici
