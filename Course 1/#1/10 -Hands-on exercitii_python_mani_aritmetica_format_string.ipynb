# %% [markdown]
# # Practică Python: Aritmetică, Șiruri, Formatare

# %% [markdown]
# Acest notebook conține exerciții pentru a exersa abilități de bază în Python precum operații aritmetice, manipularea șirurilor, conversii de tip și formatarea șirurilor.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔢 Exerciții de Aritmetică

# %% [markdown]
# ### Exercițiul 1: Adună două numere
# - Definește două variabile `a` și `b`
# - Adună-le și afișează rezultatul

# %%
a = 10  # poți schimba valoarea
b = 5   # poți schimba valoarea

# TODO: Adună a și b
result = a + b
print("Suma:", result)
# Out:
# Suma: 15

# %% [markdown]
# ### Exercițiul 2: Scade două numere
# - Scade `b` din `a` și afișează rezultatul

# %%
result = a - b
print("Diferența:", result)
# Out:
# Diferența: 5

# %% [markdown]
# ### Exercițiul 3: Înmulțire și Împărțire
# - Înmulțește și împarte `a` și `b` și afișează ambele rezultate

# %%
product = a * b
division = a / b
print("Produsul:", product)
print("Împărțirea:", division)
# Out:
# Produsul: 50
# Împărțirea: 2.0

# %% [markdown]
# ### Exercițiul 4: Modulo și Exponențiere
# - Găsește restul împărțirii lui `a` la `b`
# - Ridică `a` la puterea `b`

# %%
modulus = a % b
exponent = a ** b
print("Modulo:", modulus)
print("Exponențiere:", exponent)
# Out:
# Modulo: 0
# Exponențiere: 100000

# %% [markdown]
# ---

# %% [markdown]
# ## ✂️ Exerciții cu Șiruri de caractere

# %% [markdown]
# ### Exercițiul 5: Concatenează șiruri
# - Definește `prenume` și `nume`
# - Combină-le într-o variabilă `nume_complet` cu un spațiu între ele

# %%
first_name = "Ada"
last_name = "Lovelace"

# TODO: Concatenează numele
full_name = first_name + " " + last_name
print("Nume complet:", full_name)
# Out:
# Nume complet: Ada Lovelace

# %% [markdown]
# ### Exercițiul 6: Modifică literele
# - Convertește un șir în litere mari și litere mici

# %%
text = "Python e Distractiv!"
print("Uppercase:", text.upper())
print("Lowercase:", text.lower())
# Out:
# Uppercase: PYTHON E DISTRACTIV!
# Lowercase: python e distractiv!

# %% [markdown]
# ### Exercițiul 7: Elimină spații și Înlocuiește
# - Elimină spațiile de la început și sfârșit dintr-un șir
# - Înlocuiește un cuvânt cu altul

# %%
sentence = "   Îmi plac merele   "
print("Fără spații:", sentence.strip())
print("Înlocuit:", sentence.replace("merele", "bananele"))
# Out:
# Fără spații: Îmi plac merele
# Înlocuit:    Îmi plac bananele

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 Exerciții de Formatare a Șirurilor

# %% [markdown]
# ### Exercițiul 8: Formatare cu f-string
# - Folosește f-string pentru a introduce variabile într-o propoziție

# %%
name = "Alice"
age = 28
print(f"{name} are {age} ani.")
# Out:
# Alice are 28 ani.

# %% [markdown]
# ### Exercițiul 9: Formatare cu .format() și %
# - Scrie aceeași propoziție folosind `.format()` și formatare cu `%`

# %%
print("{} are {} ani.".format(name, age))
print("%s are %d ani." % (name, age))
# Out:
# Alice are 28 ani.
# Alice are 28 ani.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔄 Conversii de Tip

# %% [markdown]
# ### Exercițiul 10: Convertește string în int și invers
# - Convertește un număr stocat ca șir în `int`
# - Adună un număr și convertește rezultatul înapoi în șir

# %%
number_str = "100"
number_int = int(number_str)
result = number_int + 50
result_str = str(result)
print("Rezultat final (șir):", result_str)
# Out:
# Rezultat final (șir): 150
