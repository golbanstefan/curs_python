# %% [markdown]
# # 📘 Prezentare generală a funcțiilor încorporate în Python
#
# Python oferă un set bogat de funcții încorporate care simplifică sarcinile comune de programare fără a fi nevoie să importați biblioteci suplimentare.

# %% [markdown]
# ## 🔑 Puncte cheie
# - Funcțiile încorporate sunt întotdeauna disponibile și nu necesită importuri.
# - Acestea acoperă o gamă largă de operații: conversii de tip, calcule matematice, input/output și lucrul cu secvențe.
# - Puteți obține o listă a tuturor funcțiilor încorporate folosind `dir(__builtins__)`.

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# ## 📌 Funcții încorporate comune
# - `print()`: Afișează date în consolă.
# - `len()`: Returnează numărul de elemente dintr-un obiect.
# - `type()`: Returnează tipul unui obiect.
# - `int()`, `float()`, `str()`: Convertesc valorile la tipul specificat.
# - `input()`: Citește o linie de text introdusă de utilizator.
# - `sum()`, `min()`, `max()`: Funcționează pe iterabile precum liste sau tuple.
# - `sorted()`, `reversed()`: Returnează o versiune sortată sau inversată a unui iterabil.

# %%
# 🔁 Conversii de tip
numar = int("42")

print(numar)  # Output: 42
# Out:
# 42

# %%
# 📥 Input de la utilizator (comentat pentru a nu bloca rularea automată)
nume = input("Cum te numești? ")
print("Salut,", nume)
# Out:
# Salut, Stefan

# %%
# 🔢 Lucru cu secvențe
elemente = [3, 1, 4, 1, 5]
print("Numărul de elemente este:", len(elemente))       # Output: 5
print("Suma elementelor este:", sum(elemente))       # Output: 14
print("Rezultatul sortării este:", sorted(elemente))    # Output: [1, 1, 3, 4, 5]
print("Rezultatul inversării este:", list(reversed(elemente)))  # Output: <reversed object>
print("Rezultatul inversării este:", list(reversed(elemente)))
# Out:
# Numărul de elemente este: 5
# Suma elementelor este: 14
# Rezultatul sortării este: [1, 1, 3, 4, 5]
# Rezultatul inversării este: [5, 1, 4, 1, 3]
# Rezultatul inversării este: [5, 1, 4, 1, 3]

# %%
# 🧐 Verificare tipuri
print("Tipul obiectului este:", type(elemente))      # Output: <class 'list'>
# Out:
# Tipul obiectului este: <class 'list'>

# %% [markdown]
# ## ✅ Practici recomandate
# - Familiarizează-te cu cele mai utilizate funcții încorporate pentru a accelera dezvoltarea.
# - Utilizează funcțiile încorporate pentru claritate și performanță în locul unor alternative personalizate.
# - Combină funcții precum `map()`, `filter()` și `lambda` pentru cod expresiv atunci când este cazul.
#
# Aceste funcții fac parte din stilul Pythonic de a scrie cod clar și expresiv.

# %%
# 🧠 Exemplu combinat cu map, filter și lambda
numere = [1, 2, 3, 4, 5, 6]
pare = list(filter(lambda x: x % 2 == 0, numere))
patrate = list(map(lambda x: x**2, pare))
print(pare)     # [2, 4, 6]
print(patrate)  # [4, 16, 36]
# Out:
# [2, 4, 6]
# [4, 16, 36]

# %% [markdown]
# ## 📝 Note suplimentare
# Funcțiile încorporate sunt extrem de optimizate și ar trebui utilizate ori de câte ori sunt disponibile. Stăpânirea lor este un pas esențial pentru a deveni eficient în Python.
#
# Învățarea acestor funcții poate economisi timp și poate reduce erorile în cod.
